# %%
import pandas as pd 

# show all columns
pd.set_option('display.max_columns', None)

df_raw = pd.read_csv("atp_matches_2023.csv", parse_dates = ['tourney_date'])\
    .sort_values(by='tourney_date')
df_raw
# Out:
#      tourney_id    tourney_name surface  draw_size tourney_level tourney_date  \
# 0     2023-9900      United Cup    Hard         18             A   2023-01-02
# 78    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# 77    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# 76    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# 75    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# ...         ...             ...     ...        ...           ...          ...
# 2761  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2765  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2764  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2762  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2759  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
#
#       match_num  winner_id  winner_seed winner_entry         winner_name  \
# 0           300     126203          3.0          NaN        Taylor Fritz
# 78          270     200615          NaN            Q      Alexei Popyrin
# 77          271     106218          NaN          NaN        Marcos Giron
# 76          272     111456          NaN          NaN  Mackenzie Mcdonald
# 75          273     106415          NaN          NaN  Yoshihito Nishioka
# ...         ...        ...          ...          ...                 ...
# 2761        290     209098          6.0          NaN    Hamad Medjedovic
# 2765        286     209098          6.0          NaN    Hamad Medjedovic
# 2764        287     209406          8.0          NaN  Abedallah Shelbayh
# 2762        289     209414          2.0          NaN     Luca Van Assche
# 2759        292     208134          7.0          NaN          Luca Nardi
#
#      winner_hand  winner_ht winner_ioc  winner_age  loser_id  loser_seed  \
# 0              R      196.0        USA        25.1    126610         5.0
# 78             R      196.0        AUS        23.4    200000         2.0
# 77             R      180.0        USA        29.4    104755         NaN
# 76             R      178.0        USA        27.7    123755         NaN
# 75             L      170.0        JPN        27.2    208029         5.0
# ...          ...        ...        ...         ...       ...         ...
# 2761           R      188.0        SRB        20.3    209414         2.0
# 2765           R      188.0        SRB        20.3    209406         8.0
# 2764           L      180.0        JOR        20.0    210506         4.0
# 2762           R      178.0        FRA        19.5    209406         8.0
# 2759           R      185.0        ITA        20.3    207925         5.0
#
#      loser_entry             loser_name loser_hand  loser_ht loser_ioc  \
# 0            NaN      Matteo Berrettini          R     196.0       ITA
# 78           NaN  Felix Auger Aliassime          R     193.0       CAN
# 77           NaN        Richard Gasquet          R     183.0       FRA
# 76           NaN     Daniel Elahi Galan          R     191.0       COL
# 75           NaN            Holger Rune          R     188.0       DEN
# ...          ...                    ...        ...       ...       ...
# 2761         NaN        Luca Van Assche          R     178.0       FRA
# 2765         NaN     Abedallah Shelbayh          L     180.0       JOR
# 2764         NaN         Alex Michelsen          R     193.0       USA
# 2762         NaN     Abedallah Shelbayh          L     180.0       JOR
# 2759         NaN         Flavio Cobolli          R     183.0       ITA
#
#       loser_age                         score  best_of round  minutes  w_ace  \
# 0          26.7                 7-6(4) 7-6(6)        3     F    135.0   15.0
# 78         22.4                    6-4 7-6(5)        3   R32    114.0   11.0
# 77         36.5             7-6(5) 6-7(6) 7-5        3   R32    177.0   13.0
# 76         26.5                   6-3 0-0 RET        3   R32     40.0    4.0
# 75         19.6                   2-6 6-4 6-4        3   R32    125.0    0.0
# ...         ...                           ...      ...   ...      ...    ...
# 2761       19.5            4-2 2-4 4-3(7) 4-1        5    RR    108.0   13.0
# 2765       20.0         3-4(6) 4-2 4-3(5) 4-2        5    RR     92.0   18.0
# 2764       19.2               4-2 1-4 4-0 4-0        5    RR     67.0    7.0
# 2762       20.0         4-3(5) 3-4(5) 4-1 4-1        5    RR    114.0    9.0
# 2759       21.5  3-4(4) 4-2 4-3(1) 1-4 4-3(3)        5    RR    133.0    5.0
#
#       w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  \
# 0      2.0    85.0     52.0      45.0      16.0     12.0        0.0
# 78     2.0    67.0     45.0      35.0      13.0     11.0        1.0
# 77     2.0   110.0     76.0      59.0      23.0     18.0        2.0
# 76     1.0    20.0     14.0      14.0       2.0      4.0        0.0
# 75     8.0    86.0     54.0      36.0      16.0     14.0        5.0
# ...    ...     ...      ...       ...       ...      ...        ...
# 2761   2.0    74.0     45.0      35.0      15.0     12.0        6.0
# 2765   1.0    71.0     56.0      49.0       8.0     12.0        3.0
# 2764   2.0    51.0     34.0      25.0      10.0      9.0        3.0
# 2762   3.0    81.0     62.0      40.0       5.0     11.0       15.0
# 2759   0.0    93.0     67.0      51.0      14.0     14.0        5.0
#
#       w_bpFaced  l_ace  l_df  l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  \
# 0           0.0    7.0   2.0    97.0     62.0      47.0      15.0     12.0
# 78          2.0    7.0   2.0    66.0     45.0      33.0      11.0     11.0
# 77          3.0   10.0   4.0   139.0     74.0      51.0      38.0     18.0
# 76          0.0    2.0   1.0    39.0     25.0      16.0       6.0      5.0
# 75          9.0   14.0   8.0    95.0     57.0      40.0      16.0     14.0
# ...         ...    ...   ...     ...      ...       ...       ...      ...
# 2761        7.0    4.0   3.0    70.0     43.0      29.0      13.0     11.0
# 2765        3.0    9.0   2.0    76.0     50.0      36.0      14.0     12.0
# 2764        4.0    2.0   1.0    55.0     37.0      22.0       8.0     10.0
# 2762       17.0    5.0   3.0    76.0     41.0      28.0      11.0     11.0
# 2759        7.0    3.0   2.0    97.0     52.0      42.0      20.0     15.0
#
#       l_bpSaved  l_bpFaced  winner_rank  winner_rank_points  loser_rank  \
# 0           9.0        9.0          9.0              3355.0        16.0
# 78          2.0        4.0        120.0               469.0         6.0
# 77         10.0       12.0         61.0               776.0        68.0
# 76          0.0        2.0         63.0               775.0        67.0
# 75          7.0       11.0         36.0              1134.0        11.0
# ...         ...        ...          ...                 ...         ...
# 2761        9.0       11.0        110.0               582.0        70.0
# 2765        0.0        2.0        110.0               582.0       185.0
# 2764        5.0       10.0        185.0               326.0        97.0
# 2762        5.0       10.0         70.0               756.0       185.0
# 2759        3.0        5.0        115.0               549.0       100.0
#
#       loser_rank_points
# 0                2375.0
# 78               4195.0
# 77                740.0
# 76                741.0
# 75               2888.0
# ...                 ...
# 2761              756.0
# 2765              326.0
# 2764              653.0
# 2762              326.0
# 2759              640.0
#
# [2986 rows x 49 columns]

# %%
#filtering matches of top 20 players
top_20_players = ['Jannik Sinner', 'Alexander Zverev', 'Carlos Alcaraz', 'Taylor Fritz', 'Novak Djokovic', 'Casper Ruud',
                  'Jack Draper', 'Stefanos Tsitsipas', 'Andrey Rublev', 'Alex De Minaur', 'Daniil Medvedev', 'Holger Rune', 
                  'Tommy Paul', 'Ben Shelton', 'Arthur Fils', 'Lorenzo Musetti', 'Frances Tiafoe', 'Grigor Dimitrov', 
                  'Felix Auger Aliassime', 'Ugo Humbert']

# %%
#filtering to all matches of top 20 players
df_raw = df_raw[df_raw['winner_name'].isin(top_20_players) | df_raw['loser_name'].isin(top_20_players)]
df_raw
# Out:
#      tourney_id    tourney_name surface  draw_size tourney_level tourney_date  \
# 0     2023-9900      United Cup    Hard         18             A   2023-01-02
# 78    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# 75    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# 74    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# 71    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# ...         ...             ...     ...        ...           ...          ...
# 2751  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2752  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2754  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2755  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2756  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
#
#       match_num  winner_id  winner_seed winner_entry            winner_name  \
# 0           300     126203          3.0          NaN           Taylor Fritz
# 78          270     200615          NaN            Q         Alexei Popyrin
# 75          273     106415          NaN          NaN     Yoshihito Nishioka
# 74          274     105138          NaN          NaN  Roberto Bautista Agut
# 71          277     206173          6.0          NaN          Jannik Sinner
# ...         ...        ...          ...          ...                    ...
# 2751        300     209098          6.0          NaN       Hamad Medjedovic
# 2752        299     209950          1.0          NaN            Arthur Fils
# 2754        297     209950          1.0          NaN            Arthur Fils
# 2755        296     209950          1.0          NaN            Arthur Fils
# 2756        295     209950          1.0          NaN            Arthur Fils
#
#      winner_hand  winner_ht winner_ioc  winner_age  loser_id  loser_seed  \
# 0              R      196.0        USA        25.1    126610         5.0
# 78             R      196.0        AUS        23.4    200000         2.0
# 75             L      170.0        JPN        27.2    208029         5.0
# 74             R      183.0        ESP        34.7    126094         4.0
# 71             R      191.0        ITA        21.3    106378         NaN
# ...          ...        ...        ...         ...       ...         ...
# 2751           R      188.0        SRB        20.3    209950         1.0
# 2752           R      185.0        FRA        19.4    209414         2.0
# 2754           R      185.0        FRA        19.4    208502         3.0
# 2755           R      185.0        FRA        19.4    207925         5.0
# 2756           R      185.0        FRA        19.4    208134         7.0
#
#      loser_entry             loser_name loser_hand  loser_ht loser_ioc  \
# 0            NaN      Matteo Berrettini          R     196.0       ITA
# 78           NaN  Felix Auger Aliassime          R     193.0       CAN
# 75           NaN            Holger Rune          R     188.0       DEN
# 74           NaN          Andrey Rublev          R     188.0       RUS
# 71            PR            Kyle Edmund          R     188.0       GBR
# ...          ...                    ...        ...       ...       ...
# 2751         NaN            Arthur Fils          R     185.0       FRA
# 2752         NaN        Luca Van Assche          R     178.0       FRA
# 2754         NaN       Dominic Stricker          L     183.0       SUI
# 2755         NaN         Flavio Cobolli          R     183.0       ITA
# 2756         NaN             Luca Nardi          R     185.0       ITA
#
#       loser_age                      score  best_of round  minutes  w_ace  \
# 0          26.7              7-6(4) 7-6(6)        3     F    135.0   15.0
# 78         22.4                 6-4 7-6(5)        3   R32    114.0   11.0
# 75         19.6                2-6 6-4 6-4        3   R32    125.0    0.0
# 74         25.2                4-6 6-3 6-4        3   R32    109.0    8.0
# 71         27.9                    6-3 6-2        3   R32     65.0    5.0
# ...         ...                        ...      ...   ...      ...    ...
# 2751       19.4  3-4(6) 4-1 4-2 3-4(9) 4-1        5     F    131.0   19.0
# 2752       19.5      2-4 4-1 4-3(1) 4-3(6)        5    SF     97.0    9.0
# 2754       21.2      4-2 3-4(3) 4-2 4-3(5)        5    RR    104.0    8.0
# 2755       21.5                4-1 4-2 4-2        5    RR     59.0    5.0
# 2756       20.3     2-4 4-3(6) 4-2 1-4 4-2        5    RR    122.0    5.0
#
#       w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  \
# 0      2.0    85.0     52.0      45.0      16.0     12.0        0.0
# 78     2.0    67.0     45.0      35.0      13.0     11.0        1.0
# 75     8.0    86.0     54.0      36.0      16.0     14.0        5.0
# 74     1.0    79.0     54.0      40.0      17.0     15.0        2.0
# 71     1.0    41.0     25.0      23.0      13.0      9.0        0.0
# ...    ...     ...      ...       ...       ...      ...        ...
# 2751   1.0    92.0     70.0      62.0      10.0     15.0        4.0
# 2752   4.0    70.0     45.0      39.0      14.0     12.0        2.0
# 2754   3.0    77.0     46.0      35.0      18.0     12.0        2.0
# 2755   1.0    48.0     32.0      23.0      11.0      9.0        1.0
# 2756   7.0    80.0     41.0      33.0      23.0     14.0        0.0
#
#       w_bpFaced  l_ace  l_df  l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  \
# 0           0.0    7.0   2.0    97.0     62.0      47.0      15.0     12.0
# 78          2.0    7.0   2.0    66.0     45.0      33.0      11.0     11.0
# 75          9.0   14.0   8.0    95.0     57.0      40.0      16.0     14.0
# 74          4.0   15.0   6.0    81.0     52.0      40.0      11.0     14.0
# 71          0.0    1.0   2.0    48.0     21.0      15.0      11.0      8.0
# ...         ...    ...   ...     ...      ...       ...       ...      ...
# 2751        4.0   11.0   1.0    87.0     57.0      46.0      12.0     13.0
# 2752        3.0    6.0   1.0    65.0     43.0      32.0      14.0     11.0
# 2754        3.0    6.0   3.0    82.0     56.0      39.0      12.0     12.0
# 2755        2.0    5.0   3.0    39.0     19.0      11.0       8.0      8.0
# 2756        2.0    5.0   1.0    90.0     65.0      49.0      11.0     15.0
#
#       l_bpSaved  l_bpFaced  winner_rank  winner_rank_points  loser_rank  \
# 0           9.0        9.0          9.0              3355.0        16.0
# 78          2.0        4.0        120.0               469.0         6.0
# 75          7.0       11.0         36.0              1134.0        11.0
# 74          2.0        5.0         21.0              1940.0         8.0
# 71          1.0        4.0         15.0              2410.0       582.0
# ...         ...        ...          ...                 ...         ...
# 2751        1.0        4.0        110.0               582.0        36.0
# 2752        2.0        3.0         36.0              1158.0        70.0
# 2754        8.0       11.0         36.0              1158.0        94.0
# 2755        1.0        5.0         36.0              1158.0       100.0
# 2756        3.0        5.0         36.0              1158.0       115.0
#
#       loser_rank_points
# 0                2375.0
# 78               4195.0
# 75               2888.0
# 74               3930.0
# 71                 52.0
# ...                 ...
# 2751             1158.0
# 2752              756.0
# 2754              673.0
# 2755              640.0
# 2756              549.0
#
# [1103 rows x 49 columns]

# %%
top_20_players = ['Jannik Sinner', 'Alexander Zverev', 'Carlos Alcaraz', 'Taylor Fritz', 'Novak Djokovic', 'Casper Ruud',
                  'Jack Draper', 'Stefanos Tsitsipas', 'Andrey Rublev', 'Alex De Minaur', 'Daniil Medvedev', 'Holger Rune', 
                  'Tommy Paul', 'Ben Shelton', 'Arthur Fils', 'Lorenzo Musetti', 'Frances Tiafoe', 'Grigor Dimitrov', 
                  'Felix Auger Aliassime', 'Ugo Humbert']

# Create two dataframes: one for where top 20 players have won and one where they have lost
wins_df = df_raw[df_raw['winner_name'].isin(top_20_players)].copy()
losses_df = df_raw[df_raw['loser_name'].isin(top_20_players)].copy()

# For wins, I will first make a result column with 1 or 0, in this df all rows will have 1
wins_df['result'] = 1

#also adding the name of the player who won
wins_df['player'] = wins_df['winner_name']

#calculating rate of 1st serves won
wins_df['rate_1stWon'] = wins_df['w_1stWon'] / wins_df['w_1stIn']

#calculating rate of break points saved (stat explained in memo)
wins_df['bpSaved_rate'] = wins_df['w_bpSaved'] / wins_df['w_bpFaced']

# for every player, i also want return points stats, and these I will get from the loser's service points stats
wins_df['return_points_won'] = wins_df['l_svpt'] - wins_df['l_1stWon'] - wins_df['l_2ndWon'] #calculating how many return points they faced
wins_df['return_rate'] = wins_df['return_points_won'] / wins_df['l_svpt'] #rate of return points won by winner


#Doing the same calculation for the matches the players lost
losses_df['result'] = 0
losses_df['player'] = losses_df['loser_name']
losses_df['rate_1stWon'] = losses_df['l_1stWon'] / losses_df['l_1stIn']
losses_df['bpSaved_rate'] = losses_df['l_bpSaved'] / losses_df['l_bpFaced']
losses_df['return_points_won'] = losses_df['w_svpt'] - losses_df['w_1stWon'] - losses_df['w_2ndWon']
losses_df['return_rate'] = losses_df['return_points_won'] / losses_df['w_svpt']

#combining the two dataframes so now i have a new dataset of all top 20 players and the matches they won and lost in 2023
combined_df = pd.concat([wins_df, losses_df], ignore_index=True)

combined_df
# Out:
#                            tourney_id                     tourney_name  \
# 0                           2023-9900                       United Cup
# 1                           2023-2843                       Adelaide 1
# 2                           2023-2843                       Adelaide 1
# 3                           2023-2843                       Adelaide 1
# 4                           2023-2843                       Adelaide 1
# ...                               ...                              ...
# 1296  2023-M-DC-2023-FLS-M-SRB-GBR-01  Davis Cup Finals QF: SRB vs GBR
# 1297  2023-M-DC-2023-FLS-M-ITA-SRB-01  Davis Cup Finals SF: ITA vs SRB
# 1298  2023-M-DC-2023-FLS-M-ITA-SRB-01  Davis Cup Finals SF: ITA vs SRB
# 1299  2023-M-DC-2023-FLS-M-AUS-ITA-01   Davis Cup Finals F: AUS vs ITA
# 1300                        2023-7696                   NextGen Finals
#
#      surface  draw_size tourney_level tourney_date  match_num  winner_id  \
# 0       Hard         18             A   2023-01-02        300     126203
# 1       Hard         32             A   2023-01-02        277     206173
# 2       Hard         32             A   2023-01-02        279     207733
# 3       Hard         32             A   2023-01-02        281     106421
# 4       Hard         32             A   2023-01-02        285     104925
# ...      ...        ...           ...          ...        ...        ...
# 1296    Hard          2             D   2023-11-23          1     200175
# 1297    Hard          2             D   2023-11-25          2     206173
# 1298    Hard          2             D   2023-11-25          1     200175
# 1299    Hard          2             D   2023-11-26          2     206173
# 1300    Hard          8             F   2023-11-27        300     209098
#
#       winner_seed winner_entry        winner_name winner_hand  winner_ht  \
# 0             3.0          NaN       Taylor Fritz           R      196.0
# 1             6.0          NaN      Jannik Sinner           R      191.0
# 2             NaN          NaN        Jack Draper           L      193.0
# 3             3.0          NaN    Daniil Medvedev           R      198.0
# 4             1.0          NaN     Novak Djokovic           R      188.0
# ...           ...          ...                ...         ...        ...
# 1296          NaN          NaN  Miomir Kecmanovic           R      183.0
# 1297          NaN          NaN      Jannik Sinner           R      191.0
# 1298          NaN          NaN  Miomir Kecmanovic           R      183.0
# 1299          NaN          NaN      Jannik Sinner           R      191.0
# 1300          6.0          NaN   Hamad Medjedovic           R      188.0
#
#      winner_ioc  winner_age  loser_id  loser_seed loser_entry  \
# 0           USA        25.1    126610         5.0         NaN
# 1           ITA        21.3    106378         NaN          PR
# 2           GBR        21.0    126952         NaN           Q
# 3           RUS        26.8    132283         NaN         NaN
# 4           SRB        35.6    106005         NaN         NaN
# ...         ...         ...       ...         ...         ...
# 1296        SRB        24.2    207733         NaN         NaN
# 1297        ITA        22.2    104925         NaN         NaN
# 1298        SRB        24.2    207518         NaN         NaN
# 1299        ITA        22.2    200282         NaN         NaN
# 1300        SRB        20.3    209950         1.0         NaN
#
#               loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 0      Matteo Berrettini          R     196.0       ITA       26.7
# 1            Kyle Edmund          R     188.0       GBR       27.9
# 2          Soon Woo Kwon          R     180.0       KOR       25.0
# 3         Lorenzo Sonego          R     191.0       ITA       27.6
# 4     Constant Lestienne          R     180.0       FRA       30.6
# ...                  ...        ...       ...       ...        ...
# 1296         Jack Draper          L     193.0       GBR       21.9
# 1297      Novak Djokovic          R     188.0       SRB       36.4
# 1298     Lorenzo Musetti          R     185.0       ITA       21.7
# 1299      Alex De Minaur          R     183.0       AUS       24.7
# 1300         Arthur Fils          R     185.0       FRA       19.4
#
#                           score  best_of round  minutes  w_ace  w_df  w_svpt  \
# 0                 7-6(4) 7-6(6)        3     F    135.0   15.0   2.0    85.0
# 1                       6-3 6-2        3   R32     65.0    5.0   1.0    41.0
# 2                       6-2 6-1        3   R32     68.0    8.0   2.0    35.0
# 3                7-6(6) 2-1 RET        3   R32    102.0    5.0   2.0    70.0
# 4                       6-3 6-2        3   R32     74.0    4.0   2.0    47.0
# ...                         ...      ...   ...      ...    ...   ...     ...
# 1296              7-6(2) 7-6(6)        3    RR      NaN    4.0   0.0    74.0
# 1297                6-2 2-6 7-5        3    RR      NaN   12.0   5.0   105.0
# 1298             6-7(7) 6-2 6-1        3    RR      NaN    5.0   0.0    81.0
# 1299                    6-3 6-0        3    RR      NaN    5.0   1.0    48.0
# 1300  3-4(6) 4-1 4-2 3-4(9) 4-1        5     F    131.0   19.0   1.0    92.0
#
#       w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  \
# 0        52.0      45.0      16.0     12.0        0.0        0.0    7.0   2.0
# 1        25.0      23.0      13.0      9.0        0.0        0.0    1.0   2.0
# 2        18.0      16.0      13.0      7.0        3.0        3.0    2.0   3.0
# 3        45.0      30.0      15.0      8.0        9.0       10.0    1.0   1.0
# 4        29.0      25.0      13.0      9.0        1.0        1.0    3.0   1.0
# ...       ...       ...       ...      ...        ...        ...    ...   ...
# 1296     50.0      41.0      17.0     12.0        0.0        0.0   10.0   4.0
# 1297     67.0      48.0      17.0     14.0        7.0        9.0    6.0   1.0
# 1298     56.0      42.0      17.0     14.0        2.0        3.0    9.0   3.0
# 1299     34.0      25.0       7.0      7.0        1.0        1.0    2.0   1.0
# 1300     70.0      62.0      10.0     15.0        4.0        4.0   11.0   1.0
#
#       l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  \
# 0       97.0     62.0      47.0      15.0     12.0        9.0        9.0
# 1       48.0     21.0      15.0      11.0      8.0        1.0        4.0
# 2       52.0     24.0      12.0      10.0      8.0        7.0       12.0
# 3       57.0     32.0      25.0      11.0      7.0        3.0        4.0
# 4       56.0     39.0      22.0      10.0      8.0        5.0        8.0
# ...      ...      ...       ...       ...      ...        ...        ...
# 1296    89.0     55.0      43.0      17.0     12.0        4.0        4.0
# 1297    77.0     46.0      35.0      18.0     14.0        1.0        4.0
# 1298   103.0     65.0      41.0      14.0     13.0        7.0       12.0
# 1299    57.0     33.0      18.0       9.0      8.0        5.0       10.0
# 1300    87.0     57.0      46.0      12.0     13.0        1.0        4.0
#
#       winner_rank  winner_rank_points  loser_rank  loser_rank_points  result  \
# 0             9.0              3355.0        16.0             2375.0       1
# 1            15.0              2410.0       582.0               52.0       1
# 2            42.0               990.0        83.0              630.0       1
# 3             7.0              4065.0        45.0              950.0       1
# 4             5.0              4820.0        65.0              760.0       1
# ...           ...                 ...         ...                ...     ...
# 1296         55.0               905.0        60.0              856.0       0
# 1297          4.0              6490.0         1.0            11245.0       0
# 1298         55.0               905.0        27.0             1470.0       0
# 1299          4.0              6490.0        12.0             2740.0       0
# 1300        110.0               582.0        36.0             1158.0       0
#
#                player  rate_1stWon  bpSaved_rate  return_points_won  \
# 0        Taylor Fritz     0.865385           NaN               35.0
# 1       Jannik Sinner     0.920000           NaN               22.0
# 2         Jack Draper     0.888889      1.000000               30.0
# 3     Daniil Medvedev     0.666667      0.900000               21.0
# 4      Novak Djokovic     0.862069      1.000000               24.0
# ...               ...          ...           ...                ...
# 1296      Jack Draper     0.781818      1.000000               16.0
# 1297   Novak Djokovic     0.760870      0.250000               40.0
# 1298  Lorenzo Musetti     0.630769      0.583333               22.0
# 1299   Alex De Minaur     0.545455      0.500000               16.0
# 1300      Arthur Fils     0.807018      0.250000               20.0
#
#       return_rate
# 0        0.360825
# 1        0.458333
# 2        0.576923
# 3        0.368421
# 4        0.428571
# ...           ...
# 1296     0.216216
# 1297     0.380952
# 1298     0.271605
# 1299     0.333333
# 1300     0.217391
#
# [1301 rows x 55 columns]

# %%
null_counts = combined_df[['return_rate', 'bpSaved_rate', 'rate_1stWon']].isnull().sum()
print("Count of null values in each column:")
print(null_counts)
# Out:
# Count of null values in each column:
# return_rate      25
# bpSaved_rate    115
# rate_1stWon      25
# dtype: int64

# %%
#filling null values with 0
combined_df['return_rate'] = combined_df['return_rate'].fillna(0)
combined_df['bpSaved_rate'] = combined_df['bpSaved_rate'].fillna(0)
combined_df['rate_1stWon'] = combined_df['rate_1stWon'].fillna(0)
combined_df
# Out:
#                            tourney_id                     tourney_name  \
# 0                           2023-9900                       United Cup
# 1                           2023-2843                       Adelaide 1
# 2                           2023-2843                       Adelaide 1
# 3                           2023-2843                       Adelaide 1
# 4                           2023-2843                       Adelaide 1
# ...                               ...                              ...
# 1296  2023-M-DC-2023-FLS-M-SRB-GBR-01  Davis Cup Finals QF: SRB vs GBR
# 1297  2023-M-DC-2023-FLS-M-ITA-SRB-01  Davis Cup Finals SF: ITA vs SRB
# 1298  2023-M-DC-2023-FLS-M-ITA-SRB-01  Davis Cup Finals SF: ITA vs SRB
# 1299  2023-M-DC-2023-FLS-M-AUS-ITA-01   Davis Cup Finals F: AUS vs ITA
# 1300                        2023-7696                   NextGen Finals
#
#      surface  draw_size tourney_level tourney_date  match_num  winner_id  \
# 0       Hard         18             A   2023-01-02        300     126203
# 1       Hard         32             A   2023-01-02        277     206173
# 2       Hard         32             A   2023-01-02        279     207733
# 3       Hard         32             A   2023-01-02        281     106421
# 4       Hard         32             A   2023-01-02        285     104925
# ...      ...        ...           ...          ...        ...        ...
# 1296    Hard          2             D   2023-11-23          1     200175
# 1297    Hard          2             D   2023-11-25          2     206173
# 1298    Hard          2             D   2023-11-25          1     200175
# 1299    Hard          2             D   2023-11-26          2     206173
# 1300    Hard          8             F   2023-11-27        300     209098
#
#       winner_seed winner_entry        winner_name winner_hand  winner_ht  \
# 0             3.0          NaN       Taylor Fritz           R      196.0
# 1             6.0          NaN      Jannik Sinner           R      191.0
# 2             NaN          NaN        Jack Draper           L      193.0
# 3             3.0          NaN    Daniil Medvedev           R      198.0
# 4             1.0          NaN     Novak Djokovic           R      188.0
# ...           ...          ...                ...         ...        ...
# 1296          NaN          NaN  Miomir Kecmanovic           R      183.0
# 1297          NaN          NaN      Jannik Sinner           R      191.0
# 1298          NaN          NaN  Miomir Kecmanovic           R      183.0
# 1299          NaN          NaN      Jannik Sinner           R      191.0
# 1300          6.0          NaN   Hamad Medjedovic           R      188.0
#
#      winner_ioc  winner_age  loser_id  loser_seed loser_entry  \
# 0           USA        25.1    126610         5.0         NaN
# 1           ITA        21.3    106378         NaN          PR
# 2           GBR        21.0    126952         NaN           Q
# 3           RUS        26.8    132283         NaN         NaN
# 4           SRB        35.6    106005         NaN         NaN
# ...         ...         ...       ...         ...         ...
# 1296        SRB        24.2    207733         NaN         NaN
# 1297        ITA        22.2    104925         NaN         NaN
# 1298        SRB        24.2    207518         NaN         NaN
# 1299        ITA        22.2    200282         NaN         NaN
# 1300        SRB        20.3    209950         1.0         NaN
#
#               loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 0      Matteo Berrettini          R     196.0       ITA       26.7
# 1            Kyle Edmund          R     188.0       GBR       27.9
# 2          Soon Woo Kwon          R     180.0       KOR       25.0
# 3         Lorenzo Sonego          R     191.0       ITA       27.6
# 4     Constant Lestienne          R     180.0       FRA       30.6
# ...                  ...        ...       ...       ...        ...
# 1296         Jack Draper          L     193.0       GBR       21.9
# 1297      Novak Djokovic          R     188.0       SRB       36.4
# 1298     Lorenzo Musetti          R     185.0       ITA       21.7
# 1299      Alex De Minaur          R     183.0       AUS       24.7
# 1300         Arthur Fils          R     185.0       FRA       19.4
#
#                           score  best_of round  minutes  w_ace  w_df  w_svpt  \
# 0                 7-6(4) 7-6(6)        3     F    135.0   15.0   2.0    85.0
# 1                       6-3 6-2        3   R32     65.0    5.0   1.0    41.0
# 2                       6-2 6-1        3   R32     68.0    8.0   2.0    35.0
# 3                7-6(6) 2-1 RET        3   R32    102.0    5.0   2.0    70.0
# 4                       6-3 6-2        3   R32     74.0    4.0   2.0    47.0
# ...                         ...      ...   ...      ...    ...   ...     ...
# 1296              7-6(2) 7-6(6)        3    RR      NaN    4.0   0.0    74.0
# 1297                6-2 2-6 7-5        3    RR      NaN   12.0   5.0   105.0
# 1298             6-7(7) 6-2 6-1        3    RR      NaN    5.0   0.0    81.0
# 1299                    6-3 6-0        3    RR      NaN    5.0   1.0    48.0
# 1300  3-4(6) 4-1 4-2 3-4(9) 4-1        5     F    131.0   19.0   1.0    92.0
#
#       w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  \
# 0        52.0      45.0      16.0     12.0        0.0        0.0    7.0   2.0
# 1        25.0      23.0      13.0      9.0        0.0        0.0    1.0   2.0
# 2        18.0      16.0      13.0      7.0        3.0        3.0    2.0   3.0
# 3        45.0      30.0      15.0      8.0        9.0       10.0    1.0   1.0
# 4        29.0      25.0      13.0      9.0        1.0        1.0    3.0   1.0
# ...       ...       ...       ...      ...        ...        ...    ...   ...
# 1296     50.0      41.0      17.0     12.0        0.0        0.0   10.0   4.0
# 1297     67.0      48.0      17.0     14.0        7.0        9.0    6.0   1.0
# 1298     56.0      42.0      17.0     14.0        2.0        3.0    9.0   3.0
# 1299     34.0      25.0       7.0      7.0        1.0        1.0    2.0   1.0
# 1300     70.0      62.0      10.0     15.0        4.0        4.0   11.0   1.0
#
#       l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  \
# 0       97.0     62.0      47.0      15.0     12.0        9.0        9.0
# 1       48.0     21.0      15.0      11.0      8.0        1.0        4.0
# 2       52.0     24.0      12.0      10.0      8.0        7.0       12.0
# 3       57.0     32.0      25.0      11.0      7.0        3.0        4.0
# 4       56.0     39.0      22.0      10.0      8.0        5.0        8.0
# ...      ...      ...       ...       ...      ...        ...        ...
# 1296    89.0     55.0      43.0      17.0     12.0        4.0        4.0
# 1297    77.0     46.0      35.0      18.0     14.0        1.0        4.0
# 1298   103.0     65.0      41.0      14.0     13.0        7.0       12.0
# 1299    57.0     33.0      18.0       9.0      8.0        5.0       10.0
# 1300    87.0     57.0      46.0      12.0     13.0        1.0        4.0
#
#       winner_rank  winner_rank_points  loser_rank  loser_rank_points  result  \
# 0             9.0              3355.0        16.0             2375.0       1
# 1            15.0              2410.0       582.0               52.0       1
# 2            42.0               990.0        83.0              630.0       1
# 3             7.0              4065.0        45.0              950.0       1
# 4             5.0              4820.0        65.0              760.0       1
# ...           ...                 ...         ...                ...     ...
# 1296         55.0               905.0        60.0              856.0       0
# 1297          4.0              6490.0         1.0            11245.0       0
# 1298         55.0               905.0        27.0             1470.0       0
# 1299          4.0              6490.0        12.0             2740.0       0
# 1300        110.0               582.0        36.0             1158.0       0
#
#                player  rate_1stWon  bpSaved_rate  return_points_won  \
# 0        Taylor Fritz     0.865385      0.000000               35.0
# 1       Jannik Sinner     0.920000      0.000000               22.0
# 2         Jack Draper     0.888889      1.000000               30.0
# 3     Daniil Medvedev     0.666667      0.900000               21.0
# 4      Novak Djokovic     0.862069      1.000000               24.0
# ...               ...          ...           ...                ...
# 1296      Jack Draper     0.781818      1.000000               16.0
# 1297   Novak Djokovic     0.760870      0.250000               40.0
# 1298  Lorenzo Musetti     0.630769      0.583333               22.0
# 1299   Alex De Minaur     0.545455      0.500000               16.0
# 1300      Arthur Fils     0.807018      0.250000               20.0
#
#       return_rate
# 0        0.360825
# 1        0.458333
# 2        0.576923
# 3        0.368421
# 4        0.428571
# ...           ...
# 1296     0.216216
# 1297     0.380952
# 1298     0.271605
# 1299     0.333333
# 1300     0.217391
#
# [1301 rows x 55 columns]

# %%
from tqdm.auto import tqdm
tqdm.pandas()

# %%
predictors = []

for index, match in tqdm(combined_df.iterrows(), total=len(combined_df)):
    
    player = match['player']
    match_date = match['tourney_date']
    
    # Filter all matches that happened before this one
    previous_matches = combined_df[
        (combined_df['tourney_date'] < match_date) &
        (combined_df['player'] == player)
    ]
    
    # Count previous wins using the 'result' column (1 = win, 0 = loss)
    prev_match_won = previous_matches['result'].sum()

    # Average rate_1stWon from previous matches (drop NaNs to avoid errors)
    avg_rate_1stWon_so_far = previous_matches['rate_1stWon'].dropna().mean()
    avg_rate_1stWon_so_far = avg_rate_1stWon_so_far if not pd.isna(avg_rate_1stWon_so_far) else 0

    #Average bpSaved_rate from previous matches 
    avg_bpSaved_rate_so_far = previous_matches['bpSaved_rate'].dropna().mean()
    avg_bpSaved_rate_so_far = avg_bpSaved_rate_so_far if not pd.isna(avg_bpSaved_rate_so_far) else 0

    #Average return_rate from previous matches
    avg_return_rate_so_far = previous_matches['return_rate'].dropna().mean()
    avg_return_rate_so_far = avg_return_rate_so_far if not pd.isna(avg_return_rate_so_far) else 0

    predictors.append({
        'prev_match_won': prev_match_won,
        'prev_rate_1stWon_avg': avg_rate_1stWon_so_far,
        'prev_bpSaved_rate': avg_bpSaved_rate_so_far,
        'prev_return_rate': avg_return_rate_so_far
    })

predictors_df = pd.DataFrame(predictors)
# Out:
#   0%|          | 0/1301 [00:00<?, ?it/s]

# %%
predictors_df
# Out:
#       prev_match_won  prev_rate_1stWon_avg  prev_bpSaved_rate  \
# 0                  0              0.000000           0.000000
# 1                  0              0.000000           0.000000
# 2                  0              0.000000           0.000000
# 3                  0              0.000000           0.000000
# 4                  0              0.000000           0.000000
# ...              ...                   ...                ...
# 1296              19              0.776364           0.536719
# 1297              56              0.782591           0.539481
# 1298              33              0.705192           0.539059
# 1299              48              0.711608           0.543570
# 1300              21              0.698295           0.599209
#
#       prev_return_rate
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             0.000000
# 4             0.000000
# ...                ...
# 1296          0.393380
# 1297          0.416150
# 1298          0.382170
# 1299          0.400365
# 1300          0.336272
#
# [1301 rows x 4 columns]

# %%
new_df = pd.concat([combined_df.reset_index(drop=True), predictors_df.reset_index(drop=True)], axis=1)
# Out:
#    tourney_id     tourney_name surface  draw_size tourney_level tourney_date  \
# 0   2023-9900       United Cup    Hard         18             A   2023-01-02
# 1   2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 2   2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 3   2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 4   2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 5   2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 6   2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 7   2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 8   2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 9   2023-9900       United Cup    Hard         18             A   2023-01-02
# 10  2023-9900       United Cup    Hard         18             A   2023-01-02
# 11  2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 12  2023-9900       United Cup    Hard         18             A   2023-01-02
# 13  2023-9900       United Cup    Hard         18             A   2023-01-02
# 14  2023-9900       United Cup    Hard         18             A   2023-01-02
# 15  2023-9900       United Cup    Hard         18             A   2023-01-02
# 16  2023-9900       United Cup    Hard         18             A   2023-01-02
# 17  2023-9900       United Cup    Hard         18             A   2023-01-02
# 18  2023-9900       United Cup    Hard         18             A   2023-01-02
# 19  2023-9900       United Cup    Hard         18             A   2023-01-02
# 20  2023-9900       United Cup    Hard         18             A   2023-01-02
# 21  2023-9900       United Cup    Hard         18             A   2023-01-02
# 22  2023-9900       United Cup    Hard         18             A   2023-01-02
# 23  2023-9900       United Cup    Hard         18             A   2023-01-02
# 24  2023-9900       United Cup    Hard         18             A   2023-01-02
# 25  2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 26  2023-2843       Adelaide 1    Hard         32             A   2023-01-02
# 27  2023-9900       United Cup    Hard         18             A   2023-01-02
# 28  2023-9900       United Cup    Hard         18             A   2023-01-02
# 29  2023-9900       United Cup    Hard         18             A   2023-01-02
# 30  2023-9900       United Cup    Hard         18             A   2023-01-02
# 31  2023-8998       Adelaide 2    Hard         32             A   2023-01-09
# 32  2023-8998       Adelaide 2    Hard         32             A   2023-01-09
# 33  2023-8998       Adelaide 2    Hard         32             A   2023-01-09
# 34  2023-8998       Adelaide 2    Hard         32             A   2023-01-09
# 35  2023-0301         Auckland    Hard         32             A   2023-01-09
# 36   2023-580  Australian Open    Hard        128             G   2023-01-16
# 37   2023-580  Australian Open    Hard        128             G   2023-01-16
# 38   2023-580  Australian Open    Hard        128             G   2023-01-16
# 39   2023-580  Australian Open    Hard        128             G   2023-01-16
#
#     match_num  winner_id  winner_seed winner_entry         winner_name  \
# 0         300     126203          3.0          NaN        Taylor Fritz
# 1         277     206173          6.0          NaN       Jannik Sinner
# 2         279     207733          NaN          NaN         Jack Draper
# 3         281     106421          3.0          NaN     Daniil Medvedev
# 4         285     104925          1.0          NaN      Novak Djokovic
# 5         289     206173          6.0          NaN       Jannik Sinner
# 6         291     106421          3.0          NaN     Daniil Medvedev
# 7         293     104925          1.0          NaN      Novak Djokovic
# 8         297     104925          1.0          NaN      Novak Djokovic
# 9         268     105777         16.0          NaN     Grigor Dimitrov
# 10        272     126774          1.0          NaN  Stefanos Tsitsipas
# 11        296     106421          3.0          NaN     Daniil Medvedev
# 12        276     126774          1.0          NaN  Stefanos Tsitsipas
# 13        279     126207          NaN          NaN      Frances Tiafoe
# 14        283     207518          NaN          NaN     Lorenzo Musetti
# 15        288     126774          1.0          NaN  Stefanos Tsitsipas
# 16        291     207518          NaN          NaN     Lorenzo Musetti
# 17        292     126774          1.0          NaN  Stefanos Tsitsipas
# 18        295     126207          NaN          NaN      Frances Tiafoe
# 19        296     126203          3.0          NaN        Taylor Fritz
# 20        299     126207          NaN          NaN      Frances Tiafoe
# 21        252     126203          3.0          NaN        Taylor Fritz
# 22        251     126207          NaN          NaN      Frances Tiafoe
# 23        247     126207          NaN          NaN      Frances Tiafoe
# 24        248     126203          3.0          NaN        Taylor Fritz
# 25        299     104925          1.0          NaN      Novak Djokovic
# 26        300     104925          1.0          NaN      Novak Djokovic
# 27        220     134770         18.0          NaN         Casper Ruud
# 28        223     207518          NaN          NaN     Lorenzo Musetti
# 29        240     200282          7.0          NaN      Alex De Minaur
# 30        227     207518          NaN          NaN     Lorenzo Musetti
# 31        289     207733          NaN          NaN         Jack Draper
# 32        295     207733          NaN          NaN         Jack Draper
# 33        277     126205          8.0          NaN          Tommy Paul
# 34        276     207733          NaN          NaN         Jack Draper
# 35        277     210097          NaN           WC         Ben Shelton
# 36        186     105777         27.0          NaN     Grigor Dimitrov
# 37        183     208029          9.0          NaN         Holger Rune
# 38        185     200282         22.0          NaN      Alex De Minaur
# 39        187     104925          4.0          NaN      Novak Djokovic
#
#    winner_hand  winner_ht winner_ioc  winner_age  loser_id  loser_seed  \
# 0            R      196.0        USA        25.1    126610         5.0
# 1            R      191.0        ITA        21.3    106378         NaN
# 2            L      193.0        GBR        21.0    126952         NaN
# 3            R      198.0        RUS        26.8    132283         NaN
# 4            R      188.0        SRB        35.6    106005         NaN
# 5            R      191.0        ITA        21.3    106423         NaN
# 6            R      198.0        RUS        26.8    200175         NaN
# 7            R      188.0        SRB        35.6    111460         NaN
# 8            R      188.0        SRB        35.6    133430         7.0
# 9            R      191.0        BUL        31.6    105676        12.0
# 10           R      193.0        GRE        24.3    105777        16.0
# 11           R      198.0        RUS        26.8    111575         8.0
# 12           R      193.0        GRE        24.3    105676        12.0
# 13           R      188.0        USA        24.9    105554         NaN
# 14           R      185.0        ITA        20.8    207415         NaN
# 15           R      193.0        GRE        24.3    106432         8.0
# 16           R      185.0        ITA        20.8    208852         NaN
# 17           R      193.0        GRE        24.3    126610         5.0
# 18           R      188.0        USA        24.9    200390         NaN
# 19           R      196.0        USA        25.1    128034         2.0
# 20           R      188.0        USA        24.9    207518         NaN
# 21           R      196.0        USA        25.1    100644        10.0
# 22           R      188.0        USA        24.9    106214         NaN
# 23           R      188.0        USA        24.9    207830         NaN
# 24           R      196.0        USA        25.1    208103        14.0
# 25           R      188.0        SRB        35.6    106421         3.0
# 26           R      188.0        SRB        35.6    200624         NaN
# 27           R      183.0        NOR        24.0    106329        11.0
# 28           R      185.0        ITA        20.8    126340         NaN
# 29           R      183.0        AUS        23.8    104745         4.0
# 30           R      185.0        ITA        20.8    200335         NaN
# 31           L      193.0        GBR        21.0    126205         8.0
# 32           L      193.0        GBR        21.0    111575         3.0
# 33           R      185.0        USA        25.6    106331         NaN
# 34           L      193.0        GBR        21.0    132283         NaN
# 35           L      193.0        USA        20.2    202104         7.0
# 36           R      191.0        BUL        31.6    111513         NaN
# 37           R      188.0        DEN        19.7    202195         NaN
# 38           R      183.0        AUS        23.9    105173         NaN
# 39           R      188.0        SRB        35.6    111505         NaN
#
#    loser_entry             loser_name loser_hand  loser_ht loser_ioc  \
# 0          NaN      Matteo Berrettini          R     196.0       ITA
# 1           PR            Kyle Edmund          R     188.0       GBR
# 2            Q          Soon Woo Kwon          R     180.0       KOR
# 3          NaN         Lorenzo Sonego          R     191.0       ITA
# 4          NaN     Constant Lestienne          R     180.0       FRA
# 5           WC     Thanasi Kokkinakis          R     193.0       AUS
# 6          NaN      Miomir Kecmanovic          R     183.0       SRB
# 7          NaN          Quentin Halys          R     191.0       FRA
# 8          NaN       Denis Shapovalov          L     185.0       CAN
# 9          NaN           David Goffin          R     180.0       BEL
# 10         NaN        Grigor Dimitrov          R     191.0       BUL
# 11         NaN        Karen Khachanov          R     198.0       RUS
# 12         NaN           David Goffin          R     180.0       BEL
# 13         NaN           Daniel Evans          R     175.0       GBR
# 14         NaN       Daniel Michalski          R     180.0       POL
# 15         NaN            Borna Coric          R     188.0       CRO
# 16         NaN  Stefanos Sakellaridis          R     196.0       GRE
# 17         NaN      Matteo Berrettini          R     196.0       ITA
# 18         NaN             Kacper Zuk          R     183.0       POL
# 19         NaN         Hubert Hurkacz          R     196.0       POL
# 20         NaN        Lorenzo Musetti          R     185.0       ITA
# 21         NaN       Alexander Zverev          R     198.0       GER
# 22         NaN             Oscar Otte          R     193.0       GER
# 23         NaN           Tomas Machac          R     183.0       CZE
# 24         NaN           Jiri Lehecka          R     185.0       CZE
# 25         NaN        Daniil Medvedev          R     198.0       RUS
# 26         NaN        Sebastian Korda          R     196.0       USA
# 27         NaN        Thiago Monteiro          L     183.0       BRA
# 28         NaN       Viktor Durasovic          R     185.0       NOR
# 29         NaN           Rafael Nadal          L     185.0       ESP
# 30         NaN  Felipe Meligeni Alves          R     185.0       BRA
# 31         NaN             Tommy Paul          R     185.0       USA
# 32         NaN        Karen Khachanov          R     198.0       RUS
# 33          LL   Christopher Oconnell          R     183.0       AUS
# 34         NaN         Lorenzo Sonego          R     191.0       ITA
# 35         NaN         Sebastian Baez          R     170.0       ARG
# 36         NaN            Laslo Djere          R     188.0       SRB
# 37         NaN          Maxime Cressy          R     201.0       USA
# 38         NaN       Adrian Mannarino          L     180.0       FRA
# 39           Q          Enzo Couacaud          R     183.0       FRA
#
#     loser_age               score  best_of round  minutes  w_ace  w_df  \
# 0        26.7       7-6(4) 7-6(6)        3     F    135.0   15.0   2.0
# 1        27.9             6-3 6-2        3   R32     65.0    5.0   1.0
# 2        25.0             6-2 6-1        3   R32     68.0    8.0   2.0
# 3        27.6      7-6(6) 2-1 RET        3   R32    102.0    5.0   2.0
# 4        30.6             6-3 6-2        3   R32     74.0    4.0   2.0
# 5        26.7          7-6(2) 6-4        3   R16    122.0    5.0   2.0
# 6        23.3             6-0 6-3        3   R16     67.0    7.0   3.0
# 7        26.1       7-6(3) 7-6(5)        3   R16    115.0   10.0   4.0
# 8        23.7             6-3 6-4        3    QF    115.0    4.0   3.0
# 9        32.0             6-4 7-5        3    RR    102.0   10.0   7.0
# 10       31.6      4-6 6-2 7-6(4)        3    RR      NaN   12.0   1.0
# 11       26.6             6-3 6-3        3    QF     77.0    6.0   5.0
# 12       32.0             6-3 6-2        3    RR     78.0   12.0   1.0
# 13       32.6         3-6 7-5 6-3        3    RR    132.0   10.0   1.0
# 14       22.9             6-1 6-1        3    RR     57.0    8.0   0.0
# 15       26.1      6-0 6-7(4) 7-5        3    RR    151.0   20.0   1.0
# 16       18.3             6-1 6-1        3    SF     62.0    2.0   1.0
# 17       26.7      4-6 7-6(2) 6-4        3    SF    155.0    9.0   1.0
# 18       23.9             6-3 6-3        3    SF     79.0    5.0   4.0
# 19       25.8       7-6(5) 7-6(5)        3    SF    104.0   11.0   0.0
# 20       20.8         6-2 0-0 RET        3     F     34.0    3.0   1.0
# 21       25.7             6-1 6-4        3    RR     64.0    8.0   4.0
# 22       29.4             7-5 6-4        3    RR     75.0    9.0   3.0
# 23       22.2         6-3 2-4 RET        3    RR     80.0    4.0   1.0
# 24       21.1             6-3 6-4        3    RR      NaN    5.0   3.0
# 25       26.8             6-3 6-4        3    SF     90.0    5.0   3.0
# 26       22.4   6-7(8) 7-6(3) 6-4        3     F    189.0    7.0   4.0
# 27       28.5             6-3 6-2        3    RR     71.0    8.0   1.0
# 28       25.7          7-6(7) 6-3        3    RR    108.0    7.0   1.0
# 29       36.5         3-6 6-1 7-5        3    RR    162.0    3.0   6.0
# 30       24.8             6-3 6-4        3    RR      NaN    9.0   1.0
# 31       25.6             6-4 6-4        3   R16     91.0   10.0   1.0
# 32       26.6          6-4 7-6(3)        3    QF    105.0   10.0   3.0
# 33       28.6             6-4 7-5        3   R32     88.0    6.0   0.0
# 34       27.6             6-4 6-2        3   R32     82.0    2.0   1.0
# 35       22.0          7-6(1) 6-1        3   R32     82.0    9.0   1.0
# 36       27.6         6-3 6-2 6-0        5   R64     94.0    9.0   2.0
# 37       25.6         7-5 6-4 6-4        5   R64    127.0   10.0   5.0
# 38       34.5  7-6(3) 4-6 6-4 6-1        5   R64    208.0    3.0   5.0
# 39       27.8  6-1 6-7(5) 6-2 6-0        5   R64    184.0    9.0   6.0
#
#     w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  \
# 0     85.0     52.0      45.0      16.0     12.0        0.0        0.0    7.0
# 1     41.0     25.0      23.0      13.0      9.0        0.0        0.0    1.0
# 2     35.0     18.0      16.0      13.0      7.0        3.0        3.0    2.0
# 3     70.0     45.0      30.0      15.0      8.0        9.0       10.0    1.0
# 4     47.0     29.0      25.0      13.0      9.0        1.0        1.0    3.0
# 5     78.0     58.0      40.0      12.0     11.0        6.0        7.0    9.0
# 6     51.0     38.0      29.0       7.0      8.0        1.0        1.0    0.0
# 7     76.0     50.0      44.0      14.0     12.0        0.0        1.0   11.0
# 8     70.0     40.0      31.0      16.0     10.0        3.0        4.0    6.0
# 9     72.0     48.0      38.0       9.0     11.0        6.0        8.0    2.0
# 10    95.0     72.0      56.0      12.0     15.0        8.0        9.0   11.0
# 11    51.0     33.0      29.0       7.0      9.0        2.0        3.0    1.0
# 12    61.0     39.0      27.0      12.0      9.0        4.0        5.0    2.0
# 13    87.0     46.0      32.0      24.0     15.0        7.0       10.0    9.0
# 14    31.0     18.0      17.0      11.0      7.0        0.0        0.0    1.0
# 15    94.0     60.0      45.0      20.0     15.0        5.0        6.0    7.0
# 16    41.0     25.0      18.0      12.0      7.0        1.0        1.0    2.0
# 17    98.0     52.0      43.0      28.0     16.0        1.0        2.0    7.0
# 18    61.0     37.0      31.0      11.0      9.0        5.0        5.0    3.0
# 19    80.0     50.0      44.0      19.0     12.0        4.0        4.0   17.0
# 20    27.0     19.0      15.0       3.0      4.0        3.0        3.0    0.0
# 21    45.0     27.0      26.0      11.0      9.0        1.0        1.0    3.0
# 22    56.0     30.0      29.0      16.0     11.0        0.0        0.0   10.0
# 23    55.0     36.0      24.0      10.0      8.0        2.0        4.0    6.0
# 24    68.0     41.0      32.0      14.0     10.0        2.0        2.0    4.0
# 25    61.0     35.0      31.0      14.0     10.0        3.0        3.0    5.0
# 26    99.0     62.0      53.0      25.0     17.0        1.0        2.0   15.0
# 27    49.0     36.0      24.0       8.0      9.0        2.0        4.0    2.0
# 28    69.0     42.0      35.0      16.0     11.0        1.0        2.0    6.0
# 29   100.0     62.0      39.0      19.0     14.0        8.0       12.0    2.0
# 30    55.0     31.0      22.0      15.0     10.0        1.0        3.0    1.0
# 31    57.0     33.0      29.0      13.0     10.0        3.0        4.0    5.0
# 32    68.0     44.0      35.0      13.0     11.0        1.0        2.0    8.0
# 33    57.0     39.0      32.0      14.0     11.0        1.0        1.0    7.0
# 34    44.0     27.0      21.0      12.0      9.0        3.0        4.0    2.0
# 35    51.0     34.0      28.0      12.0      9.0        2.0        2.0    2.0
# 36    62.0     37.0      32.0      16.0     12.0        0.0        0.0    4.0
# 37    92.0     61.0      52.0      15.0     16.0        1.0        2.0   10.0
# 38   122.0     68.0      49.0      30.0     20.0        2.0        6.0    2.0
# 39   106.0     64.0      54.0      24.0     17.0        1.0        1.0    7.0
#
#     l_df  l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  \
# 0    2.0    97.0     62.0      47.0      15.0     12.0        9.0        9.0
# 1    2.0    48.0     21.0      15.0      11.0      8.0        1.0        4.0
# 2    3.0    52.0     24.0      12.0      10.0      8.0        7.0       12.0
# 3    1.0    57.0     32.0      25.0      11.0      7.0        3.0        4.0
# 4    1.0    56.0     39.0      22.0      10.0      8.0        5.0        8.0
# 5    3.0    72.0     45.0      33.0      13.0     11.0        1.0        3.0
# 6    0.0    42.0     31.0      13.0       6.0      7.0        3.0        7.0
# 7    2.0    82.0     48.0      39.0      16.0     12.0        4.0        5.0
# 8    7.0    72.0     38.0      25.0      14.0      9.0        5.0        8.0
# 9    2.0    64.0     33.0      22.0      16.0     11.0        3.0        7.0
# 10   2.0    87.0     55.0      44.0      19.0     15.0        6.0        8.0
# 11   2.0    60.0     42.0      25.0       6.0      9.0        3.0        7.0
# 12   1.0    49.0     33.0      22.0       4.0      8.0        2.0        6.0
# 13   3.0    82.0     46.0      35.0      17.0     15.0        5.0        9.0
# 14   1.0    40.0     28.0      12.0       5.0      7.0        4.0        9.0
# 15   2.0    88.0     59.0      44.0      10.0     15.0        2.0        7.0
# 16   1.0    43.0     26.0      15.0       5.0      7.0        4.0        9.0
# 17   2.0    89.0     58.0      48.0      18.0     16.0        1.0        2.0
# 18   3.0    68.0     41.0      26.0      12.0      9.0        6.0        9.0
# 19   1.0    82.0     62.0      51.0       7.0     12.0        2.0        2.0
# 20   0.0    21.0     12.0       8.0       3.0      4.0        1.0        3.0
# 21   5.0    60.0     48.0      31.0       3.0      8.0        3.0        6.0
# 22   0.0    58.0     30.0      23.0      18.0     11.0        0.0        2.0
# 23   5.0    59.0     37.0      27.0       6.0      7.0        3.0        5.0
# 24   1.0    48.0     31.0      24.0       8.0      9.0        1.0        3.0
# 25   2.0    48.0     31.0      23.0       9.0      9.0        1.0        3.0
# 26   4.0   129.0     76.0      59.0      27.0     17.0        5.0        7.0
# 27   5.0    41.0     27.0      16.0       3.0      8.0        1.0        6.0
# 28   3.0    81.0     45.0      28.0      19.0     10.0        8.0       10.0
# 29   4.0    92.0     56.0      34.0      16.0     14.0        7.0       13.0
# 30   2.0    50.0     33.0      19.0       8.0      9.0        0.0        4.0
# 31   1.0    58.0     34.0      23.0      12.0     10.0        2.0        5.0
# 32   3.0    75.0     48.0      36.0      11.0     11.0        4.0        6.0
# 33   1.0    66.0     41.0      32.0      10.0     11.0        3.0        5.0
# 34   1.0    50.0     26.0      14.0      11.0      9.0        4.0        8.0
# 35   3.0    67.0     49.0      26.0      11.0     10.0        7.0       10.0
# 36   7.0    73.0     35.0      22.0      13.0     11.0        6.0       12.0
# 37  14.0    84.0     47.0      37.0      17.0     16.0        3.0        7.0
# 38   3.0   123.0     83.0      51.0      19.0     19.0        3.0        9.0
# 39   2.0   140.0     92.0      53.0      20.0     16.0       14.0       21.0
#
#     winner_rank  winner_rank_points  loser_rank  loser_rank_points  result  \
# 0           9.0              3355.0        16.0             2375.0       1
# 1          15.0              2410.0       582.0               52.0       1
# 2          42.0               990.0        83.0              630.0       1
# 3           7.0              4065.0        45.0              950.0       1
# 4           5.0              4820.0        65.0              760.0       1
# 5          15.0              2410.0        93.0              592.0       1
# 6           7.0              4065.0        29.0             1420.0       1
# 7           5.0              4820.0        64.0              767.0       1
# 8           5.0              4820.0        18.0             2075.0       1
# 9          28.0              1460.0        53.0              870.0       1
# 10          4.0              5550.0        28.0             1460.0       1
# 11          7.0              4065.0        20.0             1990.0       1
# 12          4.0              5550.0        53.0              870.0       1
# 13         19.0              2000.0        27.0             1585.0       1
# 14         23.0              1865.0       260.0              204.0       1
# 15          4.0              5550.0        26.0             1685.0       1
# 16         23.0              1865.0       803.0               23.0       1
# 17          4.0              5550.0        16.0             2375.0       1
# 18         19.0              2000.0       245.0              220.0       1
# 19          9.0              3355.0        10.0             2905.0       1
# 20         19.0              2000.0        23.0             1865.0       1
# 21          9.0              3355.0        12.0             2700.0       1
# 22         19.0              2000.0        76.0              691.0       1
# 23         19.0              2000.0        97.0              580.0       1
# 24          9.0              3355.0        81.0              646.0       1
# 25          5.0              4820.0         7.0             4065.0       1
# 26          5.0              4820.0        33.0             1175.0       1
# 27          3.0              5820.0        71.0              738.0       1
# 28         23.0              1865.0       343.0              143.0       1
# 29         24.0              1790.0         2.0             6020.0       1
# 30         23.0              1865.0       166.0              343.0       1
# 31         40.0              1010.0        35.0             1185.0       1
# 32         40.0              1010.0        20.0             1885.0       1
# 33         35.0              1185.0        79.0              652.0       1
# 34         40.0              1010.0        44.0              950.0       1
# 35         92.0               584.0        41.0              987.0       1
# 36         28.0              1395.0        68.0              758.0       1
# 37         10.0              2876.0        41.0              992.0       1
# 38         24.0              1710.0        45.0              971.0       1
# 39          5.0              5070.0       191.0              302.0       1
#
#                 player  rate_1stWon  bpSaved_rate  return_points_won  \
# 0         Taylor Fritz     0.865385      0.000000               35.0
# 1        Jannik Sinner     0.920000      0.000000               22.0
# 2          Jack Draper     0.888889      1.000000               30.0
# 3      Daniil Medvedev     0.666667      0.900000               21.0
# 4       Novak Djokovic     0.862069      1.000000               24.0
# 5        Jannik Sinner     0.689655      0.857143               26.0
# 6      Daniil Medvedev     0.763158      1.000000               23.0
# 7       Novak Djokovic     0.880000      0.000000               27.0
# 8       Novak Djokovic     0.775000      0.750000               33.0
# 9      Grigor Dimitrov     0.791667      0.750000               26.0
# 10  Stefanos Tsitsipas     0.777778      0.888889               24.0
# 11     Daniil Medvedev     0.878788      0.666667               29.0
# 12  Stefanos Tsitsipas     0.692308      0.800000               23.0
# 13      Frances Tiafoe     0.695652      0.700000               30.0
# 14     Lorenzo Musetti     0.944444      0.000000               23.0
# 15  Stefanos Tsitsipas     0.750000      0.833333               34.0
# 16     Lorenzo Musetti     0.720000      1.000000               23.0
# 17  Stefanos Tsitsipas     0.826923      0.500000               23.0
# 18      Frances Tiafoe     0.837838      1.000000               30.0
# 19        Taylor Fritz     0.880000      1.000000               24.0
# 20      Frances Tiafoe     0.789474      1.000000               10.0
# 21        Taylor Fritz     0.962963      1.000000               26.0
# 22      Frances Tiafoe     0.966667      0.000000               17.0
# 23      Frances Tiafoe     0.666667      0.500000               26.0
# 24        Taylor Fritz     0.780488      1.000000               16.0
# 25      Novak Djokovic     0.885714      1.000000               16.0
# 26      Novak Djokovic     0.854839      0.500000               43.0
# 27         Casper Ruud     0.666667      0.500000               22.0
# 28     Lorenzo Musetti     0.833333      0.500000               34.0
# 29      Alex De Minaur     0.629032      0.666667               42.0
# 30     Lorenzo Musetti     0.709677      0.333333               23.0
# 31         Jack Draper     0.878788      0.750000               23.0
# 32         Jack Draper     0.795455      0.500000               28.0
# 33          Tommy Paul     0.820513      1.000000               24.0
# 34         Jack Draper     0.777778      0.750000               25.0
# 35         Ben Shelton     0.823529      1.000000               30.0
# 36     Grigor Dimitrov     0.864865      0.000000               38.0
# 37         Holger Rune     0.852459      0.500000               30.0
# 38      Alex De Minaur     0.720588      0.333333               53.0
# 39      Novak Djokovic     0.843750      1.000000               67.0
#
#     return_rate  prev_match_won  prev_rate_1stWon_avg  prev_bpSaved_rate  \
# 0      0.360825               0              0.000000           0.000000
# 1      0.458333               0              0.000000           0.000000
# 2      0.576923               0              0.000000           0.000000
# 3      0.368421               0              0.000000           0.000000
# 4      0.428571               0              0.000000           0.000000
# 5      0.361111               0              0.000000           0.000000
# 6      0.547619               0              0.000000           0.000000
# 7      0.329268               0              0.000000           0.000000
# 8      0.458333               0              0.000000           0.000000
# 9      0.406250               0              0.000000           0.000000
# 10     0.275862               0              0.000000           0.000000
# 11     0.483333               0              0.000000           0.000000
# 12     0.469388               0              0.000000           0.000000
# 13     0.365854               0              0.000000           0.000000
# 14     0.575000               0              0.000000           0.000000
# 15     0.386364               0              0.000000           0.000000
# 16     0.534884               0              0.000000           0.000000
# 17     0.258427               0              0.000000           0.000000
# 18     0.441176               0              0.000000           0.000000
# 19     0.292683               0              0.000000           0.000000
# 20     0.476190               0              0.000000           0.000000
# 21     0.433333               0              0.000000           0.000000
# 22     0.293103               0              0.000000           0.000000
# 23     0.440678               0              0.000000           0.000000
# 24     0.333333               0              0.000000           0.000000
# 25     0.333333               0              0.000000           0.000000
# 26     0.333333               0              0.000000           0.000000
# 27     0.536585               0              0.000000           0.000000
# 28     0.419753               0              0.000000           0.000000
# 29     0.456522               0              0.000000           0.000000
# 30     0.460000               0              0.000000           0.000000
# 31     0.396552               1              0.722222           0.833333
# 32     0.373333               1              0.722222           0.833333
# 33     0.363636               0              0.000000           0.000000
# 34     0.500000               1              0.722222           0.833333
# 35     0.447761               0              0.000000           0.000000
# 36     0.520548               1              0.795833           0.750000
# 37     0.357143               0              0.701754           0.636364
# 38     0.430894               1              0.653802           0.666667
# 39     0.478571               5              0.851524           0.650000
#
#     prev_return_rate
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4           0.000000
# 5           0.000000
# 6           0.000000
# 7           0.000000
# 8           0.000000
# 9           0.000000
# 10          0.000000
# 11          0.000000
# 12          0.000000
# 13          0.000000
# 14          0.000000
# 15          0.000000
# 16          0.000000
# 17          0.000000
# 18          0.000000
# 19          0.000000
# 20          0.000000
# 21          0.000000
# 22          0.000000
# 23          0.000000
# 24          0.000000
# 25          0.000000
# 26          0.000000
# 27          0.000000
# 28          0.000000
# 29          0.000000
# 30          0.000000
# 31          0.401669
# 32          0.401669
# 33          0.000000
# 34          0.401669
# 35          0.000000
# 36          0.345230
# 37          0.395349
# 38          0.371118
# 39          0.376568

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Warning: namespace ‘pbdZMQ’ is not available and has been replaced
# by .GlobalEnv when processing object ‘.pbd_env’

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# require('tidyverse')
# require('DescTools')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse
# Loading required package: DescTools

# %%
# %%R -i  new_df
#
# logistic <- glm(result ~  prev_match_won + prev_rate_1stWon_avg + prev_bpSaved_rate + prev_return_rate, data=new_df, family="binomial")
#
# print(summary(logistic))
# print(PseudoR2(logistic, which="McFadden"))
# Out:
# Call:
# glm(formula = result ~ prev_match_won + prev_rate_1stWon_avg +
#     prev_bpSaved_rate + prev_return_rate, family = "binomial",
#     data = new_df)
#
# Coefficients:
#                       Estimate Std. Error z value Pr(>|z|)
# (Intercept)           0.591146   0.270163   2.188  0.02866 *
# prev_match_won       -0.003470   0.004284  -0.810  0.41796
# prev_rate_1stWon_avg -2.625803   1.029557  -2.550  0.01076 *
# prev_bpSaved_rate     0.102943   0.917520   0.112  0.91067
# prev_return_rate      5.565702   1.596626   3.486  0.00049 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 1642.5  on 1300  degrees of freedom
# Residual deviance: 1629.6  on 1296  degrees of freedom
# AIC: 1639.6
#
# Number of Fisher Scoring iterations: 4
#
#    McFadden
# 0.007847306

# %% [markdown]
# ## Dhrumil's untouched code

# %%
predictors = []

for index, match in tqdm(df_raw.iterrows(), total=len(df_raw)):
    
    previous_matches = df_raw[df_raw['tourney_date'] < match['tourney_date']]

    # create a new variable
    number_of_previous_matches_won = len(previous_matches.query(f"winner_id == {match['winner_id']}"))

    # append to dataframe
    predictors.append({
        'prev_match_won': number_of_previous_matches_won
    })

pd.DataFrame(predictors)
# Out:
#   0%|          | 0/2986 [00:00<?, ?it/s]
#       prev_match_won
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 2981               7
# 2982               7
# 2983               2
# 2984              10
# 2985               1
#
# [2986 rows x 1 columns]

# %%
df_predictors = pd.DataFrame(predictors)
df_predictors
# Out:
#       prev_match_won
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 2981               7
# 2982               7
# 2983               2
# 2984              10
# 2985               1
#
# [2986 rows x 1 columns]

# %%
df = df_raw

# %%
assert(len(df) == len(df_predictors))

# %%
pd.concat([df, df_predictors], axis=1)
# Out:
#      tourney_id    tourney_name surface  draw_size tourney_level tourney_date  \
# 0     2023-9900      United Cup    Hard         18             A   2023-01-02
# 78    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# 77    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# 76    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# 75    2023-2843      Adelaide 1    Hard         32             A   2023-01-02
# ...         ...             ...     ...        ...           ...          ...
# 2761  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2765  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2764  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2762  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
# 2759  2023-7696  NextGen Finals    Hard          8             F   2023-11-27
#
#       match_num  winner_id  winner_seed winner_entry         winner_name  \
# 0           300     126203          3.0          NaN        Taylor Fritz
# 78          270     200615          NaN            Q      Alexei Popyrin
# 77          271     106218          NaN          NaN        Marcos Giron
# 76          272     111456          NaN          NaN  Mackenzie Mcdonald
# 75          273     106415          NaN          NaN  Yoshihito Nishioka
# ...         ...        ...          ...          ...                 ...
# 2761        290     209098          6.0          NaN    Hamad Medjedovic
# 2765        286     209098          6.0          NaN    Hamad Medjedovic
# 2764        287     209406          8.0          NaN  Abedallah Shelbayh
# 2762        289     209414          2.0          NaN     Luca Van Assche
# 2759        292     208134          7.0          NaN          Luca Nardi
#
#      winner_hand  winner_ht winner_ioc  winner_age  loser_id  loser_seed  \
# 0              R      196.0        USA        25.1    126610         5.0
# 78             R      196.0        AUS        23.4    200000         2.0
# 77             R      180.0        USA        29.4    104755         NaN
# 76             R      178.0        USA        27.7    123755         NaN
# 75             L      170.0        JPN        27.2    208029         5.0
# ...          ...        ...        ...         ...       ...         ...
# 2761           R      188.0        SRB        20.3    209414         2.0
# 2765           R      188.0        SRB        20.3    209406         8.0
# 2764           L      180.0        JOR        20.0    210506         4.0
# 2762           R      178.0        FRA        19.5    209406         8.0
# 2759           R      185.0        ITA        20.3    207925         5.0
#
#      loser_entry             loser_name loser_hand  loser_ht loser_ioc  \
# 0            NaN      Matteo Berrettini          R     196.0       ITA
# 78           NaN  Felix Auger Aliassime          R     193.0       CAN
# 77           NaN        Richard Gasquet          R     183.0       FRA
# 76           NaN     Daniel Elahi Galan          R     191.0       COL
# 75           NaN            Holger Rune          R     188.0       DEN
# ...          ...                    ...        ...       ...       ...
# 2761         NaN        Luca Van Assche          R     178.0       FRA
# 2765         NaN     Abedallah Shelbayh          L     180.0       JOR
# 2764         NaN         Alex Michelsen          R     193.0       USA
# 2762         NaN     Abedallah Shelbayh          L     180.0       JOR
# 2759         NaN         Flavio Cobolli          R     183.0       ITA
#
#       loser_age                         score  best_of round  minutes  w_ace  \
# 0          26.7                 7-6(4) 7-6(6)        3     F    135.0   15.0
# 78         22.4                    6-4 7-6(5)        3   R32    114.0   11.0
# 77         36.5             7-6(5) 6-7(6) 7-5        3   R32    177.0   13.0
# 76         26.5                   6-3 0-0 RET        3   R32     40.0    4.0
# 75         19.6                   2-6 6-4 6-4        3   R32    125.0    0.0
# ...         ...                           ...      ...   ...      ...    ...
# 2761       19.5            4-2 2-4 4-3(7) 4-1        5    RR    108.0   13.0
# 2765       20.0         3-4(6) 4-2 4-3(5) 4-2        5    RR     92.0   18.0
# 2764       19.2               4-2 1-4 4-0 4-0        5    RR     67.0    7.0
# 2762       20.0         4-3(5) 3-4(5) 4-1 4-1        5    RR    114.0    9.0
# 2759       21.5  3-4(4) 4-2 4-3(1) 1-4 4-3(3)        5    RR    133.0    5.0
#
#       w_df  w_svpt  w_1stIn  w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  \
# 0      2.0    85.0     52.0      45.0      16.0     12.0        0.0
# 78     2.0    67.0     45.0      35.0      13.0     11.0        1.0
# 77     2.0   110.0     76.0      59.0      23.0     18.0        2.0
# 76     1.0    20.0     14.0      14.0       2.0      4.0        0.0
# 75     8.0    86.0     54.0      36.0      16.0     14.0        5.0
# ...    ...     ...      ...       ...       ...      ...        ...
# 2761   2.0    74.0     45.0      35.0      15.0     12.0        6.0
# 2765   1.0    71.0     56.0      49.0       8.0     12.0        3.0
# 2764   2.0    51.0     34.0      25.0      10.0      9.0        3.0
# 2762   3.0    81.0     62.0      40.0       5.0     11.0       15.0
# 2759   0.0    93.0     67.0      51.0      14.0     14.0        5.0
#
#       w_bpFaced  l_ace  l_df  l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  \
# 0           0.0    7.0   2.0    97.0     62.0      47.0      15.0     12.0
# 78          2.0    7.0   2.0    66.0     45.0      33.0      11.0     11.0
# 77          3.0   10.0   4.0   139.0     74.0      51.0      38.0     18.0
# 76          0.0    2.0   1.0    39.0     25.0      16.0       6.0      5.0
# 75          9.0   14.0   8.0    95.0     57.0      40.0      16.0     14.0
# ...         ...    ...   ...     ...      ...       ...       ...      ...
# 2761        7.0    4.0   3.0    70.0     43.0      29.0      13.0     11.0
# 2765        3.0    9.0   2.0    76.0     50.0      36.0      14.0     12.0
# 2764        4.0    2.0   1.0    55.0     37.0      22.0       8.0     10.0
# 2762       17.0    5.0   3.0    76.0     41.0      28.0      11.0     11.0
# 2759        7.0    3.0   2.0    97.0     52.0      42.0      20.0     15.0
#
#       l_bpSaved  l_bpFaced  winner_rank  winner_rank_points  loser_rank  \
# 0           9.0        9.0          9.0              3355.0        16.0
# 78          2.0        4.0        120.0               469.0         6.0
# 77         10.0       12.0         61.0               776.0        68.0
# 76          0.0        2.0         63.0               775.0        67.0
# 75          7.0       11.0         36.0              1134.0        11.0
# ...         ...        ...          ...                 ...         ...
# 2761        9.0       11.0        110.0               582.0        70.0
# 2765        0.0        2.0        110.0               582.0       185.0
# 2764        5.0       10.0        185.0               326.0        97.0
# 2762        5.0       10.0         70.0               756.0       185.0
# 2759        3.0        5.0        115.0               549.0       100.0
#
#       loser_rank_points  prev_match_won
# 0                2375.0               0
# 78               4195.0               0
# 77                740.0               0
# 76                741.0               0
# 75               2888.0               0
# ...                 ...             ...
# 2761              756.0               0
# 2765              326.0              25
# 2764              653.0              18
# 2762              326.0              21
# 2759              640.0              20
#
# [2986 rows x 50 columns]
